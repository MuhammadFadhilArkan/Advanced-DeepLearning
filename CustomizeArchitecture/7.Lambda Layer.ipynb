# %% [markdown]
# Imports

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# %% [markdown]
# Prepare the Dataset

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Build the Model

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128),
  tf.keras.layers.Lambda(lambda x: tf.abs(x)), 
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2279 - accuracy: 0.9356
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0911 - accuracy: 0.9725
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0647 - accuracy: 0.9800
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0468 - accuracy: 0.9855
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0391 - accuracy: 0.9874
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0891 - accuracy: 0.9744
# [0.08913654088973999, 0.974399983882904]

# %% [markdown]
# Another way to use the Lambda layer is to pass in a function defined outside the model. The code below shows how a custom ReLU function is used as a custom layer in the model.

# %%
def my_relu(x):
    return K.maximum(-0.1, x)

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128),
    tf.keras.layers.Lambda(my_relu), 
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2575 - accuracy: 0.9262
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1109 - accuracy: 0.9671
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0765 - accuracy: 0.9773
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0559 - accuracy: 0.9829
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0442 - accuracy: 0.9862
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0872 - accuracy: 0.9730
# [0.08724420517683029, 0.9729999899864197]
