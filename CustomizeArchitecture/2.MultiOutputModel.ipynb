# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# Utilities

# %% [markdown]
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# Prepare the Data

# %% [markdown]
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# Build the Model

# %% [markdown]
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. [y1_output, y2_output]) when we instantiate the Model() class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Configure parameters

# %% [markdown]
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 6ms/step - loss: 257.9803 - y1_output_loss: 123.6147 - y2_output_loss: 134.3656 - y1_output_root_mean_squared_error: 11.1182 - y2_output_root_mean_squared_error: 11.5916 - val_loss: 65.2032 - val_y1_output_loss: 20.3914 - val_y2_output_loss: 44.8118 - val_y1_output_root_mean_squared_error: 4.5157 - val_y2_output_root_mean_squared_error: 6.6942
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 35.6272 - y1_output_loss: 13.5834 - y2_output_loss: 22.0438 - y1_output_root_mean_squared_error: 3.6856 - y2_output_root_mean_squared_error: 4.6951 - val_loss: 54.0715 - val_y1_output_loss: 12.0227 - val_y2_output_loss: 42.0488 - val_y1_output_root_mean_squared_error: 3.4674 - val_y2_output_root_mean_squared_error: 6.4845
# Epoch 3/500
# 62/62 [==============================] - 0s 2ms/step - loss: 28.4215 - y1_output_loss: 10.6956 - y2_output_loss: 17.7259 - y1_output_root_mean_squared_error: 3.2704 - y2_output_root_mean_squared_error: 4.2102 - val_loss: 37.6201 - val_y1_output_loss: 11.9124 - val_y2_output_loss: 25.7077 - val_y1_output_root_mean_squared_error: 3.4514 - val_y2_output_root_mean_squared_error: 5.0703
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 24.5848 - y1_output_loss: 9.5425 - y2_output_loss: 15.0424 - y1_output_root_mean_squared_error: 3.0891 - y2_output_root_mean_squared_error: 3.8784 - val_loss: 30.2600 - val_y1_output_loss: 10.5597 - val_y2_output_loss: 19.7004 - val_y1_output_root_mean_squared_error: 3.2496 - val_y2_output_root_mean_squared_error: 4.4385
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.4084 - y1_output_loss: 8.7834 - y2_output_loss: 12.6250 - y1_output_root_mean_squared_error: 2.9637 - y2_output_root_mean_squared_error: 3.5532 - val_loss: 27.1525 - val_y1_output_loss: 10.2419 - val_y2_output_loss: 16.9107 - val_y1_output_root_mean_squared_error: 3.2003 - val_y2_output_root_mean_squared_error: 4.1123
# Epoch 6/500
# 62/62 [==============================] - 0s 2ms/step - loss: 25.5577 - y1_output_loss: 9.7097 - y2_output_loss: 15.8481 - y1_output_root_mean_squared_error: 3.1160 - y2_output_root_mean_squared_error: 3.9810 - val_loss: 27.1912 - val_y1_output_loss: 11.3035 - val_y2_output_loss: 15.8877 - val_y1_output_root_mean_squared_error: 3.3621 - val_y2_output_root_mean_squared_error: 3.9859
# Epoch 7/500
# 62/62 [==============================] - 0s 3ms/step - loss: 21.8936 - y1_output_loss: 8.4267 - y2_output_loss: 13.4670 - y1_output_root_mean_squared_error: 2.9029 - y2_output_root_mean_squared_error: 3.6697 - val_loss: 23.7895 - val_y1_output_loss: 8.9443 - val_y2_output_loss: 14.8452 - val_y1_output_root_mean_squared_error: 2.9907 - val_y2_output_root_mean_squared_error: 3.8529
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 22.1948 - y1_output_loss: 8.6016 - y2_output_loss: 13.5933 - y1_output_root_mean_squared_error: 2.9328 - y2_output_root_mean_squared_error: 3.6869 - val_loss: 33.3958 - val_y1_output_loss: 9.4901 - val_y2_output_loss: 23.9057 - val_y1_output_root_mean_squared_error: 3.0806 - val_y2_output_root_mean_squared_error: 4.8893
# Epoch 9/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.8033 - y1_output_loss: 8.3064 - y2_output_loss: 12.4969 - y1_output_root_mean_squared_error: 2.8821 - y2_output_root_mean_squared_error: 3.5351 - val_loss: 28.6803 - val_y1_output_loss: 9.4226 - val_y2_output_loss: 19.2578 - val_y1_output_root_mean_squared_error: 3.0696 - val_y2_output_root_mean_squared_error: 4.3884
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.0052 - y1_output_loss: 7.7104 - y2_output_loss: 11.2948 - y1_output_root_mean_squared_error: 2.7768 - y2_output_root_mean_squared_error: 3.3608 - val_loss: 24.9210 - val_y1_output_loss: 10.6856 - val_y2_output_loss: 14.2355 - val_y1_output_root_mean_squared_error: 3.2689 - val_y2_output_root_mean_squared_error: 3.7730
# Epoch 11/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.2071 - y1_output_loss: 8.1821 - y2_output_loss: 12.0251 - y1_output_root_mean_squared_error: 2.8604 - y2_output_root_mean_squared_error: 3.4677 - val_loss: 57.4578 - val_y1_output_loss: 19.3791 - val_y2_output_loss: 38.0787 - val_y1_output_root_mean_squared_error: 4.4022 - val_y2_output_root_mean_squared_error: 6.1708
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 22.1084 - y1_output_loss: 8.1790 - y2_output_loss: 13.9294 - y1_output_root_mean_squared_error: 2.8599 - y2_output_root_mean_squared_error: 3.7322 - val_loss: 27.4056 - val_y1_output_loss: 10.8743 - val_y2_output_loss: 16.5313 - val_y1_output_root_mean_squared_error: 3.2976 - val_y2_output_root_mean_squared_error: 4.0659
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.4023 - y1_output_loss: 7.9740 - y2_output_loss: 13.4283 - y1_output_root_mean_squared_error: 2.8238 - y2_output_root_mean_squared_error: 3.6645 - val_loss: 25.5900 - val_y1_output_loss: 9.3713 - val_y2_output_loss: 16.2188 - val_y1_output_root_mean_squared_error: 3.0613 - val_y2_output_root_mean_squared_error: 4.0273
# Epoch 14/500
# 62/62 [==============================] - 0s 3ms/step - loss: 19.4994 - y1_output_loss: 7.3624 - y2_output_loss: 12.1369 - y1_output_root_mean_squared_error: 2.7134 - y2_output_root_mean_squared_error: 3.4838 - val_loss: 21.4930 - val_y1_output_loss: 8.7415 - val_y2_output_loss: 12.7515 - val_y1_output_root_mean_squared_error: 2.9566 - val_y2_output_root_mean_squared_error: 3.5709
# Epoch 15/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.0728 - y1_output_loss: 6.7836 - y2_output_loss: 10.2892 - y1_output_root_mean_squared_error: 2.6045 - y2_output_root_mean_squared_error: 3.2077 - val_loss: 23.1640 - val_y1_output_loss: 9.2777 - val_y2_output_loss: 13.8863 - val_y1_output_root_mean_squared_error: 3.0459 - val_y2_output_root_mean_squared_error: 3.7264
# Epoch 16/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.9215 - y1_output_loss: 7.8952 - y2_output_loss: 12.0263 - y1_output_root_mean_squared_error: 2.8098 - y2_output_root_mean_squared_error: 3.4679 - val_loss: 27.5846 - val_y1_output_loss: 10.7178 - val_y2_output_loss: 16.8668 - val_y1_output_root_mean_squared_error: 3.2738 - val_y2_output_root_mean_squared_error: 4.1069
# Epoch 17/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.3161 - y1_output_loss: 7.1200 - y2_output_loss: 12.1960 - y1_output_root_mean_squared_error: 2.6683 - y2_output_root_mean_squared_error: 3.4923 - val_loss: 25.8616 - val_y1_output_loss: 8.8079 - val_y2_output_loss: 17.0537 - val_y1_output_root_mean_squared_error: 2.9678 - val_y2_output_root_mean_squared_error: 4.1296
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.4387 - y1_output_loss: 6.7040 - y2_output_loss: 10.7346 - y1_output_root_mean_squared_error: 2.5892 - y2_output_root_mean_squared_error: 3.2764 - val_loss: 28.1552 - val_y1_output_loss: 9.5276 - val_y2_output_loss: 18.6276 - val_y1_output_root_mean_squared_error: 3.0867 - val_y2_output_root_mean_squared_error: 4.3160
# Epoch 19/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.7907 - y1_output_loss: 6.2525 - y2_output_loss: 9.5382 - y1_output_root_mean_squared_error: 2.5005 - y2_output_root_mean_squared_error: 3.0884 - val_loss: 29.5100 - val_y1_output_loss: 11.3976 - val_y2_output_loss: 18.1124 - val_y1_output_root_mean_squared_error: 3.3760 - val_y2_output_root_mean_squared_error: 4.2559
# Epoch 20/500
# 62/62 [==============================] - 0s 3ms/step - loss: 20.5126 - y1_output_loss: 7.7124 - y2_output_loss: 12.8002 - y1_output_root_mean_squared_error: 2.7771 - y2_output_root_mean_squared_error: 3.5777 - val_loss: 23.5165 - val_y1_output_loss: 11.5529 - val_y2_output_loss: 11.9635 - val_y1_output_root_mean_squared_error: 3.3990 - val_y2_output_root_mean_squared_error: 3.4588
# Epoch 21/500
# 62/62 [==============================] - 0s 3ms/step - loss: 14.5549 - y1_output_loss: 5.8680 - y2_output_loss: 8.6869 - y1_output_root_mean_squared_error: 2.4224 - y2_output_root_mean_squared_error: 2.9473 - val_loss: 44.2592 - val_y1_output_loss: 15.2851 - val_y2_output_loss: 28.9741 - val_y1_output_root_mean_squared_error: 3.9096 - val_y2_output_root_mean_squared_error: 5.3828
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.0912 - y1_output_loss: 6.5509 - y2_output_loss: 10.5403 - y1_output_root_mean_squared_error: 2.5595 - y2_output_root_mean_squared_error: 3.2466 - val_loss: 29.8142 - val_y1_output_loss: 9.5076 - val_y2_output_loss: 20.3066 - val_y1_output_root_mean_squared_error: 3.0834 - val_y2_output_root_mean_squared_error: 4.5063
# Epoch 23/500
# 62/62 [==============================] - 0s 3ms/step - loss: 16.3803 - y1_output_loss: 6.0836 - y2_output_loss: 10.2967 - y1_output_root_mean_squared_error: 2.4665 - y2_output_root_mean_squared_error: 3.2088 - val_loss: 15.8538 - val_y1_output_loss: 7.1045 - val_y2_output_loss: 8.7493 - val_y1_output_root_mean_squared_error: 2.6654 - val_y2_output_root_mean_squared_error: 2.9579
# Epoch 24/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.1885 - y1_output_loss: 6.1430 - y2_output_loss: 12.0456 - y1_output_root_mean_squared_error: 2.4785 - y2_output_root_mean_squared_error: 3.4707 - val_loss: 44.9062 - val_y1_output_loss: 11.2194 - val_y2_output_loss: 33.6868 - val_y1_output_root_mean_squared_error: 3.3495 - val_y2_output_root_mean_squared_error: 5.8040
# Epoch 25/500
# 62/62 [==============================] - 0s 3ms/step - loss: 17.8540 - y1_output_loss: 6.2666 - y2_output_loss: 11.5874 - y1_output_root_mean_squared_error: 2.5033 - y2_output_root_mean_squared_error: 3.4040 - val_loss: 49.2344 - val_y1_output_loss: 17.7193 - val_y2_output_loss: 31.5151 - val_y1_output_root_mean_squared_error: 4.2094 - val_y2_output_root_mean_squared_error: 5.6138
# Epoch 26/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.2632 - y1_output_loss: 5.5243 - y2_output_loss: 9.7389 - y1_output_root_mean_squared_error: 2.3504 - y2_output_root_mean_squared_error: 3.1207 - val_loss: 17.6558 - val_y1_output_loss: 7.2756 - val_y2_output_loss: 10.3802 - val_y1_output_root_mean_squared_error: 2.6973 - val_y2_output_root_mean_squared_error: 3.2218
# Epoch 27/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.7724 - y1_output_loss: 4.4809 - y2_output_loss: 7.2915 - y1_output_root_mean_squared_error: 2.1168 - y2_output_root_mean_squared_error: 2.7003 - val_loss: 12.9670 - val_y1_output_loss: 5.3711 - val_y2_output_loss: 7.5959 - val_y1_output_root_mean_squared_error: 2.3176 - val_y2_output_root_mean_squared_error: 2.7561
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.7789 - y1_output_loss: 4.8396 - y2_output_loss: 7.9394 - y1_output_root_mean_squared_error: 2.1999 - y2_output_root_mean_squared_error: 2.8177 - val_loss: 13.7154 - val_y1_output_loss: 5.4344 - val_y2_output_loss: 8.2810 - val_y1_output_root_mean_squared_error: 2.3312 - val_y2_output_root_mean_squared_error: 2.8777
# Epoch 29/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.0883 - y1_output_loss: 5.2673 - y2_output_loss: 8.8210 - y1_output_root_mean_squared_error: 2.2951 - y2_output_root_mean_squared_error: 2.9700 - val_loss: 18.5829 - val_y1_output_loss: 6.3779 - val_y2_output_loss: 12.2050 - val_y1_output_root_mean_squared_error: 2.5254 - val_y2_output_root_mean_squared_error: 3.4936
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.7161 - y1_output_loss: 4.5034 - y2_output_loss: 7.2127 - y1_output_root_mean_squared_error: 2.1221 - y2_output_root_mean_squared_error: 2.6856 - val_loss: 22.7937 - val_y1_output_loss: 8.1239 - val_y2_output_loss: 14.6698 - val_y1_output_root_mean_squared_error: 2.8502 - val_y2_output_root_mean_squared_error: 3.8301
# Epoch 31/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.6954 - y1_output_loss: 4.5919 - y2_output_loss: 8.1035 - y1_output_root_mean_squared_error: 2.1429 - y2_output_root_mean_squared_error: 2.8467 - val_loss: 71.1996 - val_y1_output_loss: 14.6381 - val_y2_output_loss: 56.5615 - val_y1_output_root_mean_squared_error: 3.8260 - val_y2_output_root_mean_squared_error: 7.5207
# Epoch 32/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.6461 - y1_output_loss: 4.3237 - y2_output_loss: 8.3225 - y1_output_root_mean_squared_error: 2.0793 - y2_output_root_mean_squared_error: 2.8849 - val_loss: 16.1999 - val_y1_output_loss: 6.6240 - val_y2_output_loss: 9.5759 - val_y1_output_root_mean_squared_error: 2.5737 - val_y2_output_root_mean_squared_error: 3.0945
# Epoch 33/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.8643 - y1_output_loss: 4.0745 - y2_output_loss: 6.7898 - y1_output_root_mean_squared_error: 2.0185 - y2_output_root_mean_squared_error: 2.6057 - val_loss: 10.8546 - val_y1_output_loss: 4.4092 - val_y2_output_loss: 6.4453 - val_y1_output_root_mean_squared_error: 2.0998 - val_y2_output_root_mean_squared_error: 2.5388
# Epoch 34/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.3873 - y1_output_loss: 3.5231 - y2_output_loss: 5.8641 - y1_output_root_mean_squared_error: 1.8770 - y2_output_root_mean_squared_error: 2.4216 - val_loss: 14.1577 - val_y1_output_loss: 5.8008 - val_y2_output_loss: 8.3569 - val_y1_output_root_mean_squared_error: 2.4085 - val_y2_output_root_mean_squared_error: 2.8908
# Epoch 35/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.8299 - y1_output_loss: 3.5582 - y2_output_loss: 6.2717 - y1_output_root_mean_squared_error: 1.8863 - y2_output_root_mean_squared_error: 2.5043 - val_loss: 39.0345 - val_y1_output_loss: 15.2565 - val_y2_output_loss: 23.7780 - val_y1_output_root_mean_squared_error: 3.9060 - val_y2_output_root_mean_squared_error: 4.8763
# Epoch 36/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.6164 - y1_output_loss: 3.9144 - y2_output_loss: 6.7021 - y1_output_root_mean_squared_error: 1.9785 - y2_output_root_mean_squared_error: 2.5888 - val_loss: 9.4597 - val_y1_output_loss: 3.8654 - val_y2_output_loss: 5.5943 - val_y1_output_root_mean_squared_error: 1.9661 - val_y2_output_root_mean_squared_error: 2.3652
# Epoch 37/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.7431 - y1_output_loss: 3.4914 - y2_output_loss: 6.2516 - y1_output_root_mean_squared_error: 1.8685 - y2_output_root_mean_squared_error: 2.5003 - val_loss: 10.4946 - val_y1_output_loss: 3.3827 - val_y2_output_loss: 7.1120 - val_y1_output_root_mean_squared_error: 1.8392 - val_y2_output_root_mean_squared_error: 2.6668
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.7101 - y1_output_loss: 3.0265 - y2_output_loss: 5.6836 - y1_output_root_mean_squared_error: 1.7397 - y2_output_root_mean_squared_error: 2.3840 - val_loss: 20.3227 - val_y1_output_loss: 7.5373 - val_y2_output_loss: 12.7854 - val_y1_output_root_mean_squared_error: 2.7454 - val_y2_output_root_mean_squared_error: 3.5757
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.7667 - y1_output_loss: 2.6570 - y2_output_loss: 5.1097 - y1_output_root_mean_squared_error: 1.6300 - y2_output_root_mean_squared_error: 2.2605 - val_loss: 14.3927 - val_y1_output_loss: 4.1408 - val_y2_output_loss: 10.2519 - val_y1_output_root_mean_squared_error: 2.0349 - val_y2_output_root_mean_squared_error: 3.2019
# Epoch 40/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.2315 - y1_output_loss: 3.0654 - y2_output_loss: 6.1661 - y1_output_root_mean_squared_error: 1.7508 - y2_output_root_mean_squared_error: 2.4832 - val_loss: 12.3443 - val_y1_output_loss: 4.4688 - val_y2_output_loss: 7.8755 - val_y1_output_root_mean_squared_error: 2.1140 - val_y2_output_root_mean_squared_error: 2.8063
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.0105 - y1_output_loss: 2.4681 - y2_output_loss: 4.5425 - y1_output_root_mean_squared_error: 1.5710 - y2_output_root_mean_squared_error: 2.1313 - val_loss: 9.2053 - val_y1_output_loss: 3.8030 - val_y2_output_loss: 5.4023 - val_y1_output_root_mean_squared_error: 1.9501 - val_y2_output_root_mean_squared_error: 2.3243
# Epoch 42/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.4595 - y1_output_loss: 2.8837 - y2_output_loss: 5.5759 - y1_output_root_mean_squared_error: 1.6981 - y2_output_root_mean_squared_error: 2.3613 - val_loss: 16.9205 - val_y1_output_loss: 6.3587 - val_y2_output_loss: 10.5618 - val_y1_output_root_mean_squared_error: 2.5216 - val_y2_output_root_mean_squared_error: 3.2499
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.6411 - y1_output_loss: 2.2610 - y2_output_loss: 4.3801 - y1_output_root_mean_squared_error: 1.5037 - y2_output_root_mean_squared_error: 2.0929 - val_loss: 9.3028 - val_y1_output_loss: 3.6002 - val_y2_output_loss: 5.7025 - val_y1_output_root_mean_squared_error: 1.8974 - val_y2_output_root_mean_squared_error: 2.3880
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.2255 - y1_output_loss: 2.6095 - y2_output_loss: 5.6160 - y1_output_root_mean_squared_error: 1.6154 - y2_output_root_mean_squared_error: 2.3698 - val_loss: 11.6058 - val_y1_output_loss: 3.9489 - val_y2_output_loss: 7.6568 - val_y1_output_root_mean_squared_error: 1.9872 - val_y2_output_root_mean_squared_error: 2.7671
# Epoch 45/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.7817 - y1_output_loss: 2.4426 - y2_output_loss: 5.3391 - y1_output_root_mean_squared_error: 1.5629 - y2_output_root_mean_squared_error: 2.3107 - val_loss: 9.6665 - val_y1_output_loss: 3.2097 - val_y2_output_loss: 6.4568 - val_y1_output_root_mean_squared_error: 1.7916 - val_y2_output_root_mean_squared_error: 2.5410
# Epoch 46/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.9644 - y1_output_loss: 2.2807 - y2_output_loss: 4.6837 - y1_output_root_mean_squared_error: 1.5102 - y2_output_root_mean_squared_error: 2.1642 - val_loss: 8.9031 - val_y1_output_loss: 3.0072 - val_y2_output_loss: 5.8959 - val_y1_output_root_mean_squared_error: 1.7341 - val_y2_output_root_mean_squared_error: 2.4281
# Epoch 47/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.1765 - y1_output_loss: 2.6939 - y2_output_loss: 6.4826 - y1_output_root_mean_squared_error: 1.6413 - y2_output_root_mean_squared_error: 2.5461 - val_loss: 7.7782 - val_y1_output_loss: 2.9500 - val_y2_output_loss: 4.8282 - val_y1_output_root_mean_squared_error: 1.7176 - val_y2_output_root_mean_squared_error: 2.1973
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.1968 - y1_output_loss: 1.9780 - y2_output_loss: 4.2188 - y1_output_root_mean_squared_error: 1.4064 - y2_output_root_mean_squared_error: 2.0540 - val_loss: 6.9403 - val_y1_output_loss: 2.3188 - val_y2_output_loss: 4.6215 - val_y1_output_root_mean_squared_error: 1.5228 - val_y2_output_root_mean_squared_error: 2.1498
# Epoch 49/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.2771 - y1_output_loss: 2.0409 - y2_output_loss: 4.2362 - y1_output_root_mean_squared_error: 1.4286 - y2_output_root_mean_squared_error: 2.0582 - val_loss: 7.5034 - val_y1_output_loss: 2.3003 - val_y2_output_loss: 5.2031 - val_y1_output_root_mean_squared_error: 1.5167 - val_y2_output_root_mean_squared_error: 2.2810
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.0417 - y1_output_loss: 2.0798 - y2_output_loss: 4.9619 - y1_output_root_mean_squared_error: 1.4422 - y2_output_root_mean_squared_error: 2.2275 - val_loss: 7.1336 - val_y1_output_loss: 2.4405 - val_y2_output_loss: 4.6931 - val_y1_output_root_mean_squared_error: 1.5622 - val_y2_output_root_mean_squared_error: 2.1664
# Epoch 51/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.6003 - y1_output_loss: 1.8330 - y2_output_loss: 4.7674 - y1_output_root_mean_squared_error: 1.3539 - y2_output_root_mean_squared_error: 2.1834 - val_loss: 7.0428 - val_y1_output_loss: 2.4018 - val_y2_output_loss: 4.6410 - val_y1_output_root_mean_squared_error: 1.5498 - val_y2_output_root_mean_squared_error: 2.1543
# Epoch 52/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.9927 - y1_output_loss: 2.2101 - y2_output_loss: 5.7826 - y1_output_root_mean_squared_error: 1.4866 - y2_output_root_mean_squared_error: 2.4047 - val_loss: 62.7225 - val_y1_output_loss: 9.1983 - val_y2_output_loss: 53.5242 - val_y1_output_root_mean_squared_error: 3.0329 - val_y2_output_root_mean_squared_error: 7.3160
# Epoch 53/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.3924 - y1_output_loss: 2.3687 - y2_output_loss: 5.0237 - y1_output_root_mean_squared_error: 1.5391 - y2_output_root_mean_squared_error: 2.2414 - val_loss: 11.4423 - val_y1_output_loss: 3.6445 - val_y2_output_loss: 7.7977 - val_y1_output_root_mean_squared_error: 1.9091 - val_y2_output_root_mean_squared_error: 2.7924
# Epoch 54/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.2474 - y1_output_loss: 2.0029 - y2_output_loss: 4.2446 - y1_output_root_mean_squared_error: 1.4152 - y2_output_root_mean_squared_error: 2.0602 - val_loss: 11.0965 - val_y1_output_loss: 2.7637 - val_y2_output_loss: 8.3329 - val_y1_output_root_mean_squared_error: 1.6624 - val_y2_output_root_mean_squared_error: 2.8867
# Epoch 55/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.3178 - y1_output_loss: 1.9271 - y2_output_loss: 4.3907 - y1_output_root_mean_squared_error: 1.3882 - y2_output_root_mean_squared_error: 2.0954 - val_loss: 10.9939 - val_y1_output_loss: 2.8989 - val_y2_output_loss: 8.0950 - val_y1_output_root_mean_squared_error: 1.7026 - val_y2_output_root_mean_squared_error: 2.8452
# Epoch 56/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.2300 - y1_output_loss: 1.8182 - y2_output_loss: 5.4118 - y1_output_root_mean_squared_error: 1.3484 - y2_output_root_mean_squared_error: 2.3263 - val_loss: 6.3181 - val_y1_output_loss: 1.8869 - val_y2_output_loss: 4.4311 - val_y1_output_root_mean_squared_error: 1.3736 - val_y2_output_root_mean_squared_error: 2.1050
# Epoch 57/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.1163 - y1_output_loss: 1.8194 - y2_output_loss: 4.2969 - y1_output_root_mean_squared_error: 1.3489 - y2_output_root_mean_squared_error: 2.0729 - val_loss: 8.1130 - val_y1_output_loss: 2.1481 - val_y2_output_loss: 5.9649 - val_y1_output_root_mean_squared_error: 1.4656 - val_y2_output_root_mean_squared_error: 2.4423
# Epoch 58/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.3503 - y1_output_loss: 1.5370 - y2_output_loss: 3.8133 - y1_output_root_mean_squared_error: 1.2398 - y2_output_root_mean_squared_error: 1.9528 - val_loss: 8.8470 - val_y1_output_loss: 1.7961 - val_y2_output_loss: 7.0509 - val_y1_output_root_mean_squared_error: 1.3402 - val_y2_output_root_mean_squared_error: 2.6553
# Epoch 59/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.4645 - y1_output_loss: 1.3314 - y2_output_loss: 3.1331 - y1_output_root_mean_squared_error: 1.1539 - y2_output_root_mean_squared_error: 1.7701 - val_loss: 6.1385 - val_y1_output_loss: 2.1138 - val_y2_output_loss: 4.0246 - val_y1_output_root_mean_squared_error: 1.4539 - val_y2_output_root_mean_squared_error: 2.0062
# Epoch 60/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.9042 - y1_output_loss: 1.4156 - y2_output_loss: 3.4886 - y1_output_root_mean_squared_error: 1.1898 - y2_output_root_mean_squared_error: 1.8678 - val_loss: 5.9381 - val_y1_output_loss: 1.7541 - val_y2_output_loss: 4.1841 - val_y1_output_root_mean_squared_error: 1.3244 - val_y2_output_root_mean_squared_error: 2.0455
# Epoch 61/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.9428 - y1_output_loss: 1.6405 - y2_output_loss: 4.3023 - y1_output_root_mean_squared_error: 1.2808 - y2_output_root_mean_squared_error: 2.0742 - val_loss: 6.0869 - val_y1_output_loss: 1.7467 - val_y2_output_loss: 4.3402 - val_y1_output_root_mean_squared_error: 1.3216 - val_y2_output_root_mean_squared_error: 2.0833
# Epoch 62/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.4776 - y1_output_loss: 1.2962 - y2_output_loss: 3.1814 - y1_output_root_mean_squared_error: 1.1385 - y2_output_root_mean_squared_error: 1.7837 - val_loss: 8.4132 - val_y1_output_loss: 1.6742 - val_y2_output_loss: 6.7390 - val_y1_output_root_mean_squared_error: 1.2939 - val_y2_output_root_mean_squared_error: 2.5960
# Epoch 63/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.0688 - y1_output_loss: 2.6879 - y2_output_loss: 6.3810 - y1_output_root_mean_squared_error: 1.6395 - y2_output_root_mean_squared_error: 2.5261 - val_loss: 5.4100 - val_y1_output_loss: 1.5741 - val_y2_output_loss: 3.8358 - val_y1_output_root_mean_squared_error: 1.2546 - val_y2_output_root_mean_squared_error: 1.9585
# Epoch 64/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.5079 - y1_output_loss: 1.2813 - y2_output_loss: 4.2267 - y1_output_root_mean_squared_error: 1.1319 - y2_output_root_mean_squared_error: 2.0559 - val_loss: 6.9002 - val_y1_output_loss: 1.6627 - val_y2_output_loss: 5.2375 - val_y1_output_root_mean_squared_error: 1.2895 - val_y2_output_root_mean_squared_error: 2.2886
# Epoch 65/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.5947 - y1_output_loss: 1.1973 - y2_output_loss: 3.3974 - y1_output_root_mean_squared_error: 1.0942 - y2_output_root_mean_squared_error: 1.8432 - val_loss: 7.2504 - val_y1_output_loss: 1.6181 - val_y2_output_loss: 5.6323 - val_y1_output_root_mean_squared_error: 1.2721 - val_y2_output_root_mean_squared_error: 2.3732
# Epoch 66/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.2528 - y1_output_loss: 1.3502 - y2_output_loss: 3.9026 - y1_output_root_mean_squared_error: 1.1620 - y2_output_root_mean_squared_error: 1.9755 - val_loss: 5.5343 - val_y1_output_loss: 1.5500 - val_y2_output_loss: 3.9844 - val_y1_output_root_mean_squared_error: 1.2450 - val_y2_output_root_mean_squared_error: 1.9961
# Epoch 67/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.5333 - y1_output_loss: 1.2336 - y2_output_loss: 3.2997 - y1_output_root_mean_squared_error: 1.1107 - y2_output_root_mean_squared_error: 1.8165 - val_loss: 5.2626 - val_y1_output_loss: 1.3421 - val_y2_output_loss: 3.9205 - val_y1_output_root_mean_squared_error: 1.1585 - val_y2_output_root_mean_squared_error: 1.9800
# Epoch 68/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.1924 - y1_output_loss: 1.0677 - y2_output_loss: 3.1247 - y1_output_root_mean_squared_error: 1.0333 - y2_output_root_mean_squared_error: 1.7677 - val_loss: 27.7217 - val_y1_output_loss: 4.3434 - val_y2_output_loss: 23.3783 - val_y1_output_root_mean_squared_error: 2.0841 - val_y2_output_root_mean_squared_error: 4.8351
# Epoch 69/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.0367 - y1_output_loss: 1.2598 - y2_output_loss: 3.7769 - y1_output_root_mean_squared_error: 1.1224 - y2_output_root_mean_squared_error: 1.9434 - val_loss: 11.7269 - val_y1_output_loss: 3.0575 - val_y2_output_loss: 8.6693 - val_y1_output_root_mean_squared_error: 1.7486 - val_y2_output_root_mean_squared_error: 2.9444
# Epoch 70/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.6050 - y1_output_loss: 1.2057 - y2_output_loss: 3.3993 - y1_output_root_mean_squared_error: 1.0980 - y2_output_root_mean_squared_error: 1.8437 - val_loss: 7.1800 - val_y1_output_loss: 2.8072 - val_y2_output_loss: 4.3727 - val_y1_output_root_mean_squared_error: 1.6755 - val_y2_output_root_mean_squared_error: 2.0911
# Epoch 71/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.3663 - y1_output_loss: 1.5217 - y2_output_loss: 3.8446 - y1_output_root_mean_squared_error: 1.2336 - y2_output_root_mean_squared_error: 1.9608 - val_loss: 7.2226 - val_y1_output_loss: 1.6587 - val_y2_output_loss: 5.5639 - val_y1_output_root_mean_squared_error: 1.2879 - val_y2_output_root_mean_squared_error: 2.3588
# Epoch 72/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.3547 - y1_output_loss: 1.1175 - y2_output_loss: 3.2372 - y1_output_root_mean_squared_error: 1.0571 - y2_output_root_mean_squared_error: 1.7992 - val_loss: 5.0214 - val_y1_output_loss: 1.3433 - val_y2_output_loss: 3.6781 - val_y1_output_root_mean_squared_error: 1.1590 - val_y2_output_root_mean_squared_error: 1.9178
# Epoch 73/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.8904 - y1_output_loss: 0.9848 - y2_output_loss: 2.9056 - y1_output_root_mean_squared_error: 0.9924 - y2_output_root_mean_squared_error: 1.7046 - val_loss: 6.2812 - val_y1_output_loss: 1.3581 - val_y2_output_loss: 4.9232 - val_y1_output_root_mean_squared_error: 1.1654 - val_y2_output_root_mean_squared_error: 2.2188
# Epoch 74/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.4938 - y1_output_loss: 1.2155 - y2_output_loss: 3.2783 - y1_output_root_mean_squared_error: 1.1025 - y2_output_root_mean_squared_error: 1.8106 - val_loss: 8.7062 - val_y1_output_loss: 2.6686 - val_y2_output_loss: 6.0376 - val_y1_output_root_mean_squared_error: 1.6336 - val_y2_output_root_mean_squared_error: 2.4572
# Epoch 75/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.8411 - y1_output_loss: 1.0220 - y2_output_loss: 2.8191 - y1_output_root_mean_squared_error: 1.0109 - y2_output_root_mean_squared_error: 1.6790 - val_loss: 7.6552 - val_y1_output_loss: 1.3416 - val_y2_output_loss: 6.3135 - val_y1_output_root_mean_squared_error: 1.1583 - val_y2_output_root_mean_squared_error: 2.5127
# Epoch 76/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.7790 - y1_output_loss: 0.9611 - y2_output_loss: 2.8179 - y1_output_root_mean_squared_error: 0.9803 - y2_output_root_mean_squared_error: 1.6787 - val_loss: 7.8585 - val_y1_output_loss: 1.5660 - val_y2_output_loss: 6.2925 - val_y1_output_root_mean_squared_error: 1.2514 - val_y2_output_root_mean_squared_error: 2.5085
# Epoch 77/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.9952 - y1_output_loss: 0.9720 - y2_output_loss: 3.0232 - y1_output_root_mean_squared_error: 0.9859 - y2_output_root_mean_squared_error: 1.7387 - val_loss: 4.0959 - val_y1_output_loss: 0.9008 - val_y2_output_loss: 3.1952 - val_y1_output_root_mean_squared_error: 0.9491 - val_y2_output_root_mean_squared_error: 1.7875
# Epoch 78/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3975 - y1_output_loss: 0.7824 - y2_output_loss: 2.6151 - y1_output_root_mean_squared_error: 0.8845 - y2_output_root_mean_squared_error: 1.6171 - val_loss: 3.8990 - val_y1_output_loss: 0.8740 - val_y2_output_loss: 3.0250 - val_y1_output_root_mean_squared_error: 0.9349 - val_y2_output_root_mean_squared_error: 1.7392
# Epoch 79/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.0510 - y1_output_loss: 1.1731 - y2_output_loss: 3.8779 - y1_output_root_mean_squared_error: 1.0831 - y2_output_root_mean_squared_error: 1.9692 - val_loss: 9.8517 - val_y1_output_loss: 2.1617 - val_y2_output_loss: 7.6900 - val_y1_output_root_mean_squared_error: 1.4703 - val_y2_output_root_mean_squared_error: 2.7731
# Epoch 80/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.4942 - y1_output_loss: 0.8538 - y2_output_loss: 2.6404 - y1_output_root_mean_squared_error: 0.9240 - y2_output_root_mean_squared_error: 1.6249 - val_loss: 4.3612 - val_y1_output_loss: 0.8279 - val_y2_output_loss: 3.5333 - val_y1_output_root_mean_squared_error: 0.9099 - val_y2_output_root_mean_squared_error: 1.8797
# Epoch 81/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.2122 - y1_output_loss: 1.2438 - y2_output_loss: 3.9684 - y1_output_root_mean_squared_error: 1.1152 - y2_output_root_mean_squared_error: 1.9921 - val_loss: 7.0410 - val_y1_output_loss: 2.6267 - val_y2_output_loss: 4.4142 - val_y1_output_root_mean_squared_error: 1.6207 - val_y2_output_root_mean_squared_error: 2.1010
# Epoch 82/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.4999 - y1_output_loss: 1.2778 - y2_output_loss: 3.2221 - y1_output_root_mean_squared_error: 1.1304 - y2_output_root_mean_squared_error: 1.7950 - val_loss: 3.7495 - val_y1_output_loss: 0.7631 - val_y2_output_loss: 2.9864 - val_y1_output_root_mean_squared_error: 0.8735 - val_y2_output_root_mean_squared_error: 1.7281
# Epoch 83/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.4114 - y1_output_loss: 0.8493 - y2_output_loss: 2.5621 - y1_output_root_mean_squared_error: 0.9216 - y2_output_root_mean_squared_error: 1.6007 - val_loss: 6.9090 - val_y1_output_loss: 1.1179 - val_y2_output_loss: 5.7912 - val_y1_output_root_mean_squared_error: 1.0573 - val_y2_output_root_mean_squared_error: 2.4065
# Epoch 84/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.2301 - y1_output_loss: 0.7055 - y2_output_loss: 2.5246 - y1_output_root_mean_squared_error: 0.8399 - y2_output_root_mean_squared_error: 1.5889 - val_loss: 9.7879 - val_y1_output_loss: 1.6609 - val_y2_output_loss: 8.1271 - val_y1_output_root_mean_squared_error: 1.2887 - val_y2_output_root_mean_squared_error: 2.8508
# Epoch 85/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.2471 - y1_output_loss: 1.2092 - y2_output_loss: 3.0379 - y1_output_root_mean_squared_error: 1.0997 - y2_output_root_mean_squared_error: 1.7430 - val_loss: 4.1332 - val_y1_output_loss: 1.0249 - val_y2_output_loss: 3.1083 - val_y1_output_root_mean_squared_error: 1.0124 - val_y2_output_root_mean_squared_error: 1.7630
# Epoch 86/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.2228 - y1_output_loss: 1.7745 - y2_output_loss: 5.4483 - y1_output_root_mean_squared_error: 1.3321 - y2_output_root_mean_squared_error: 2.3342 - val_loss: 11.2998 - val_y1_output_loss: 4.3434 - val_y2_output_loss: 6.9564 - val_y1_output_root_mean_squared_error: 2.0841 - val_y2_output_root_mean_squared_error: 2.6375
# Epoch 87/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.5011 - y1_output_loss: 1.1047 - y2_output_loss: 3.3964 - y1_output_root_mean_squared_error: 1.0511 - y2_output_root_mean_squared_error: 1.8429 - val_loss: 10.9262 - val_y1_output_loss: 1.1955 - val_y2_output_loss: 9.7307 - val_y1_output_root_mean_squared_error: 1.0934 - val_y2_output_root_mean_squared_error: 3.1194
# Epoch 88/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.5350 - y1_output_loss: 0.9067 - y2_output_loss: 2.6284 - y1_output_root_mean_squared_error: 0.9522 - y2_output_root_mean_squared_error: 1.6212 - val_loss: 4.0922 - val_y1_output_loss: 0.9346 - val_y2_output_loss: 3.1575 - val_y1_output_root_mean_squared_error: 0.9668 - val_y2_output_root_mean_squared_error: 1.7769
# Epoch 89/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.6084 - y1_output_loss: 0.6056 - y2_output_loss: 2.0029 - y1_output_root_mean_squared_error: 0.7782 - y2_output_root_mean_squared_error: 1.4152 - val_loss: 4.2302 - val_y1_output_loss: 0.7081 - val_y2_output_loss: 3.5221 - val_y1_output_root_mean_squared_error: 0.8415 - val_y2_output_root_mean_squared_error: 1.8767
# Epoch 90/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3815 - y1_output_loss: 0.7358 - y2_output_loss: 2.6458 - y1_output_root_mean_squared_error: 0.8578 - y2_output_root_mean_squared_error: 1.6266 - val_loss: 8.0940 - val_y1_output_loss: 1.2104 - val_y2_output_loss: 6.8836 - val_y1_output_root_mean_squared_error: 1.1002 - val_y2_output_root_mean_squared_error: 2.6237
# Epoch 91/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.5721 - y1_output_loss: 0.7935 - y2_output_loss: 2.7786 - y1_output_root_mean_squared_error: 0.8908 - y2_output_root_mean_squared_error: 1.6669 - val_loss: 3.3392 - val_y1_output_loss: 0.6506 - val_y2_output_loss: 2.6886 - val_y1_output_root_mean_squared_error: 0.8066 - val_y2_output_root_mean_squared_error: 1.6397
# Epoch 92/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.5558 - y1_output_loss: 0.8514 - y2_output_loss: 2.7044 - y1_output_root_mean_squared_error: 0.9227 - y2_output_root_mean_squared_error: 1.6445 - val_loss: 4.0341 - val_y1_output_loss: 0.6582 - val_y2_output_loss: 3.3759 - val_y1_output_root_mean_squared_error: 0.8113 - val_y2_output_root_mean_squared_error: 1.8374
# Epoch 93/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8933 - y1_output_loss: 0.6222 - y2_output_loss: 2.2710 - y1_output_root_mean_squared_error: 0.7888 - y2_output_root_mean_squared_error: 1.5070 - val_loss: 3.6305 - val_y1_output_loss: 0.8157 - val_y2_output_loss: 2.8149 - val_y1_output_root_mean_squared_error: 0.9031 - val_y2_output_root_mean_squared_error: 1.6778
# Epoch 94/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6815 - y1_output_loss: 0.6162 - y2_output_loss: 2.0653 - y1_output_root_mean_squared_error: 0.7850 - y2_output_root_mean_squared_error: 1.4371 - val_loss: 4.8816 - val_y1_output_loss: 0.6020 - val_y2_output_loss: 4.2795 - val_y1_output_root_mean_squared_error: 0.7759 - val_y2_output_root_mean_squared_error: 2.0687
# Epoch 95/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.7563 - y1_output_loss: 0.6023 - y2_output_loss: 2.1540 - y1_output_root_mean_squared_error: 0.7761 - y2_output_root_mean_squared_error: 1.4676 - val_loss: 4.1019 - val_y1_output_loss: 0.9072 - val_y2_output_loss: 3.1947 - val_y1_output_root_mean_squared_error: 0.9525 - val_y2_output_root_mean_squared_error: 1.7874
# Epoch 96/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8122 - y1_output_loss: 0.6551 - y2_output_loss: 2.1571 - y1_output_root_mean_squared_error: 0.8094 - y2_output_root_mean_squared_error: 1.4687 - val_loss: 8.6413 - val_y1_output_loss: 2.3336 - val_y2_output_loss: 6.3077 - val_y1_output_root_mean_squared_error: 1.5276 - val_y2_output_root_mean_squared_error: 2.5115
# Epoch 97/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5992 - y1_output_loss: 0.6235 - y2_output_loss: 1.9757 - y1_output_root_mean_squared_error: 0.7896 - y2_output_root_mean_squared_error: 1.4056 - val_loss: 5.1083 - val_y1_output_loss: 0.8482 - val_y2_output_loss: 4.2601 - val_y1_output_root_mean_squared_error: 0.9210 - val_y2_output_root_mean_squared_error: 2.0640
# Epoch 98/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.2672 - y1_output_loss: 0.7700 - y2_output_loss: 2.4973 - y1_output_root_mean_squared_error: 0.8775 - y2_output_root_mean_squared_error: 1.5803 - val_loss: 5.4761 - val_y1_output_loss: 1.1314 - val_y2_output_loss: 4.3447 - val_y1_output_root_mean_squared_error: 1.0637 - val_y2_output_root_mean_squared_error: 2.0844
# Epoch 99/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3678 - y1_output_loss: 0.7869 - y2_output_loss: 2.5809 - y1_output_root_mean_squared_error: 0.8871 - y2_output_root_mean_squared_error: 1.6065 - val_loss: 4.3641 - val_y1_output_loss: 1.8283 - val_y2_output_loss: 2.5359 - val_y1_output_root_mean_squared_error: 1.3521 - val_y2_output_root_mean_squared_error: 1.5924
# Epoch 100/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.1983 - y1_output_loss: 0.7329 - y2_output_loss: 2.4655 - y1_output_root_mean_squared_error: 0.8561 - y2_output_root_mean_squared_error: 1.5702 - val_loss: 4.3077 - val_y1_output_loss: 0.8369 - val_y2_output_loss: 3.4708 - val_y1_output_root_mean_squared_error: 0.9148 - val_y2_output_root_mean_squared_error: 1.8630
# Epoch 101/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.4442 - y1_output_loss: 0.8518 - y2_output_loss: 2.5924 - y1_output_root_mean_squared_error: 0.9229 - y2_output_root_mean_squared_error: 1.6101 - val_loss: 4.0873 - val_y1_output_loss: 0.7944 - val_y2_output_loss: 3.2929 - val_y1_output_root_mean_squared_error: 0.8913 - val_y2_output_root_mean_squared_error: 1.8146
# Epoch 102/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0865 - y1_output_loss: 0.6496 - y2_output_loss: 2.4368 - y1_output_root_mean_squared_error: 0.8060 - y2_output_root_mean_squared_error: 1.5610 - val_loss: 5.4327 - val_y1_output_loss: 1.5896 - val_y2_output_loss: 3.8431 - val_y1_output_root_mean_squared_error: 1.2608 - val_y2_output_root_mean_squared_error: 1.9604
# Epoch 103/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8211 - y1_output_loss: 0.6490 - y2_output_loss: 2.1721 - y1_output_root_mean_squared_error: 0.8056 - y2_output_root_mean_squared_error: 1.4738 - val_loss: 6.3419 - val_y1_output_loss: 2.0306 - val_y2_output_loss: 4.3113 - val_y1_output_root_mean_squared_error: 1.4250 - val_y2_output_root_mean_squared_error: 2.0764
# Epoch 104/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8131 - y1_output_loss: 0.6551 - y2_output_loss: 2.1580 - y1_output_root_mean_squared_error: 0.8094 - y2_output_root_mean_squared_error: 1.4690 - val_loss: 3.5875 - val_y1_output_loss: 0.7061 - val_y2_output_loss: 2.8814 - val_y1_output_root_mean_squared_error: 0.8403 - val_y2_output_root_mean_squared_error: 1.6975
# Epoch 105/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5898 - y1_output_loss: 0.4950 - y2_output_loss: 2.0948 - y1_output_root_mean_squared_error: 0.7036 - y2_output_root_mean_squared_error: 1.4473 - val_loss: 4.0800 - val_y1_output_loss: 0.7134 - val_y2_output_loss: 3.3666 - val_y1_output_root_mean_squared_error: 0.8446 - val_y2_output_root_mean_squared_error: 1.8348
# Epoch 106/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5287 - y1_output_loss: 0.6638 - y2_output_loss: 1.8649 - y1_output_root_mean_squared_error: 0.8147 - y2_output_root_mean_squared_error: 1.3656 - val_loss: 4.2150 - val_y1_output_loss: 1.2365 - val_y2_output_loss: 2.9785 - val_y1_output_root_mean_squared_error: 1.1120 - val_y2_output_root_mean_squared_error: 1.7258
# Epoch 107/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.7657 - y1_output_loss: 0.5445 - y2_output_loss: 2.2212 - y1_output_root_mean_squared_error: 0.7379 - y2_output_root_mean_squared_error: 1.4904 - val_loss: 3.8262 - val_y1_output_loss: 0.7118 - val_y2_output_loss: 3.1144 - val_y1_output_root_mean_squared_error: 0.8437 - val_y2_output_root_mean_squared_error: 1.7648
# Epoch 108/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7320 - y1_output_loss: 0.5997 - y2_output_loss: 2.1323 - y1_output_root_mean_squared_error: 0.7744 - y2_output_root_mean_squared_error: 1.4602 - val_loss: 5.2271 - val_y1_output_loss: 0.8774 - val_y2_output_loss: 4.3497 - val_y1_output_root_mean_squared_error: 0.9367 - val_y2_output_root_mean_squared_error: 2.0856
# Epoch 109/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.5018 - y1_output_loss: 0.8862 - y2_output_loss: 2.6156 - y1_output_root_mean_squared_error: 0.9414 - y2_output_root_mean_squared_error: 1.6173 - val_loss: 3.7830 - val_y1_output_loss: 0.6587 - val_y2_output_loss: 3.1243 - val_y1_output_root_mean_squared_error: 0.8116 - val_y2_output_root_mean_squared_error: 1.7676
# Epoch 110/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.6631 - y1_output_loss: 0.5182 - y2_output_loss: 2.1448 - y1_output_root_mean_squared_error: 0.7199 - y2_output_root_mean_squared_error: 1.4645 - val_loss: 3.7764 - val_y1_output_loss: 0.5771 - val_y2_output_loss: 3.1994 - val_y1_output_root_mean_squared_error: 0.7596 - val_y2_output_root_mean_squared_error: 1.7887
# Epoch 111/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.8157 - y1_output_loss: 0.6007 - y2_output_loss: 2.2150 - y1_output_root_mean_squared_error: 0.7750 - y2_output_root_mean_squared_error: 1.4883 - val_loss: 3.7305 - val_y1_output_loss: 0.5233 - val_y2_output_loss: 3.2072 - val_y1_output_root_mean_squared_error: 0.7234 - val_y2_output_root_mean_squared_error: 1.7909
# Epoch 112/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9245 - y1_output_loss: 0.6641 - y2_output_loss: 2.2604 - y1_output_root_mean_squared_error: 0.8149 - y2_output_root_mean_squared_error: 1.5035 - val_loss: 3.7550 - val_y1_output_loss: 0.6668 - val_y2_output_loss: 3.0883 - val_y1_output_root_mean_squared_error: 0.8165 - val_y2_output_root_mean_squared_error: 1.7574
# Epoch 113/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.8455 - y1_output_loss: 0.6775 - y2_output_loss: 2.1680 - y1_output_root_mean_squared_error: 0.8231 - y2_output_root_mean_squared_error: 1.4724 - val_loss: 7.0761 - val_y1_output_loss: 1.2042 - val_y2_output_loss: 5.8719 - val_y1_output_root_mean_squared_error: 1.0973 - val_y2_output_root_mean_squared_error: 2.4232
# Epoch 114/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.1601 - y1_output_loss: 0.7340 - y2_output_loss: 2.4261 - y1_output_root_mean_squared_error: 0.8567 - y2_output_root_mean_squared_error: 1.5576 - val_loss: 3.8443 - val_y1_output_loss: 0.6319 - val_y2_output_loss: 3.2124 - val_y1_output_root_mean_squared_error: 0.7949 - val_y2_output_root_mean_squared_error: 1.7923
# Epoch 115/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5815 - y1_output_loss: 0.5242 - y2_output_loss: 2.0573 - y1_output_root_mean_squared_error: 0.7240 - y2_output_root_mean_squared_error: 1.4343 - val_loss: 4.1308 - val_y1_output_loss: 1.1837 - val_y2_output_loss: 2.9470 - val_y1_output_root_mean_squared_error: 1.0880 - val_y2_output_root_mean_squared_error: 1.7167
# Epoch 116/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.6478 - y1_output_loss: 0.5390 - y2_output_loss: 2.1089 - y1_output_root_mean_squared_error: 0.7342 - y2_output_root_mean_squared_error: 1.4522 - val_loss: 3.1156 - val_y1_output_loss: 0.5975 - val_y2_output_loss: 2.5181 - val_y1_output_root_mean_squared_error: 0.7730 - val_y2_output_root_mean_squared_error: 1.5869
# Epoch 117/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.1350 - y1_output_loss: 0.7451 - y2_output_loss: 2.3898 - y1_output_root_mean_squared_error: 0.8632 - y2_output_root_mean_squared_error: 1.5459 - val_loss: 3.8561 - val_y1_output_loss: 1.0320 - val_y2_output_loss: 2.8241 - val_y1_output_root_mean_squared_error: 1.0159 - val_y2_output_root_mean_squared_error: 1.6805
# Epoch 118/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.2691 - y1_output_loss: 0.5132 - y2_output_loss: 1.7559 - y1_output_root_mean_squared_error: 0.7164 - y2_output_root_mean_squared_error: 1.3251 - val_loss: 2.9771 - val_y1_output_loss: 0.4037 - val_y2_output_loss: 2.5734 - val_y1_output_root_mean_squared_error: 0.6353 - val_y2_output_root_mean_squared_error: 1.6042
# Epoch 119/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.0539 - y1_output_loss: 0.4772 - y2_output_loss: 1.5766 - y1_output_root_mean_squared_error: 0.6908 - y2_output_root_mean_squared_error: 1.2556 - val_loss: 3.4250 - val_y1_output_loss: 0.5649 - val_y2_output_loss: 2.8601 - val_y1_output_root_mean_squared_error: 0.7516 - val_y2_output_root_mean_squared_error: 1.6912
# Epoch 120/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.4458 - y1_output_loss: 0.5241 - y2_output_loss: 1.9217 - y1_output_root_mean_squared_error: 0.7240 - y2_output_root_mean_squared_error: 1.3862 - val_loss: 10.6448 - val_y1_output_loss: 1.9000 - val_y2_output_loss: 8.7448 - val_y1_output_root_mean_squared_error: 1.3784 - val_y2_output_root_mean_squared_error: 2.9572
# Epoch 121/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8307 - y1_output_loss: 0.6832 - y2_output_loss: 2.1475 - y1_output_root_mean_squared_error: 0.8266 - y2_output_root_mean_squared_error: 1.4654 - val_loss: 4.1594 - val_y1_output_loss: 0.6985 - val_y2_output_loss: 3.4609 - val_y1_output_root_mean_squared_error: 0.8357 - val_y2_output_root_mean_squared_error: 1.8603
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4718 - y1_output_loss: 0.1273 - y2_output_loss: 0.3444 - y1_output_root_mean_squared_error: 0.3568 - y2_output_root_mean_squared_error: 0.5869 - val_loss: 1.9184 - val_y1_output_loss: 0.3168 - val_y2_output_loss: 1.6016 - val_y1_output_root_mean_squared_error: 0.5628 - val_y2_output_root_mean_squared_error: 1.2656
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6848 - y1_output_loss: 0.1792 - y2_output_loss: 0.5056 - y1_output_root_mean_squared_error: 0.4233 - y2_output_root_mean_squared_error: 0.7110 - val_loss: 1.2047 - val_y1_output_loss: 0.2365 - val_y2_output_loss: 0.9681 - val_y1_output_root_mean_squared_error: 0.4864 - val_y2_output_root_mean_squared_error: 0.9839
# Epoch 463/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4538 - y1_output_loss: 0.1450 - y2_output_loss: 0.3088 - y1_output_root_mean_squared_error: 0.3808 - y2_output_root_mean_squared_error: 0.5557 - val_loss: 1.1811 - val_y1_output_loss: 0.2271 - val_y2_output_loss: 0.9540 - val_y1_output_root_mean_squared_error: 0.4765 - val_y2_output_root_mean_squared_error: 0.9768
# Epoch 464/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3584 - y1_output_loss: 0.1190 - y2_output_loss: 0.2394 - y1_output_root_mean_squared_error: 0.3449 - y2_output_root_mean_squared_error: 0.4893 - val_loss: 1.1791 - val_y1_output_loss: 0.2447 - val_y2_output_loss: 0.9344 - val_y1_output_root_mean_squared_error: 0.4947 - val_y2_output_root_mean_squared_error: 0.9666
# Epoch 465/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3554 - y1_output_loss: 0.1287 - y2_output_loss: 0.2268 - y1_output_root_mean_squared_error: 0.3587 - y2_output_root_mean_squared_error: 0.4762 - val_loss: 1.1119 - val_y1_output_loss: 0.2525 - val_y2_output_loss: 0.8593 - val_y1_output_root_mean_squared_error: 0.5025 - val_y2_output_root_mean_squared_error: 0.9270
# Epoch 466/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4146 - y1_output_loss: 0.1255 - y2_output_loss: 0.2891 - y1_output_root_mean_squared_error: 0.3542 - y2_output_root_mean_squared_error: 0.5377 - val_loss: 1.2470 - val_y1_output_loss: 0.2631 - val_y2_output_loss: 0.9839 - val_y1_output_root_mean_squared_error: 0.5129 - val_y2_output_root_mean_squared_error: 0.9919
# Epoch 467/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4090 - y1_output_loss: 0.1307 - y2_output_loss: 0.2783 - y1_output_root_mean_squared_error: 0.3615 - y2_output_root_mean_squared_error: 0.5276 - val_loss: 1.1456 - val_y1_output_loss: 0.2219 - val_y2_output_loss: 0.9237 - val_y1_output_root_mean_squared_error: 0.4710 - val_y2_output_root_mean_squared_error: 0.9611
# Epoch 468/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5343 - y1_output_loss: 0.1457 - y2_output_loss: 0.3885 - y1_output_root_mean_squared_error: 0.3818 - y2_output_root_mean_squared_error: 0.6233 - val_loss: 1.3013 - val_y1_output_loss: 0.2236 - val_y2_output_loss: 1.0777 - val_y1_output_root_mean_squared_error: 0.4729 - val_y2_output_root_mean_squared_error: 1.0381
# Epoch 469/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.7332 - y1_output_loss: 0.1876 - y2_output_loss: 0.5456 - y1_output_root_mean_squared_error: 0.4331 - y2_output_root_mean_squared_error: 0.7386 - val_loss: 1.2165 - val_y1_output_loss: 0.2158 - val_y2_output_loss: 1.0006 - val_y1_output_root_mean_squared_error: 0.4646 - val_y2_output_root_mean_squared_error: 1.0003
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4805 - y1_output_loss: 0.1380 - y2_output_loss: 0.3424 - y1_output_root_mean_squared_error: 0.3715 - y2_output_root_mean_squared_error: 0.5852 - val_loss: 1.4055 - val_y1_output_loss: 0.2850 - val_y2_output_loss: 1.1204 - val_y1_output_root_mean_squared_error: 0.5339 - val_y2_output_root_mean_squared_error: 1.0585
# Epoch 471/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3835 - y1_output_loss: 0.1356 - y2_output_loss: 0.2479 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.4979 - val_loss: 1.6260 - val_y1_output_loss: 0.2342 - val_y2_output_loss: 1.3919 - val_y1_output_root_mean_squared_error: 0.4839 - val_y2_output_root_mean_squared_error: 1.1798
# Epoch 472/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5079 - y1_output_loss: 0.1467 - y2_output_loss: 0.3612 - y1_output_root_mean_squared_error: 0.3830 - y2_output_root_mean_squared_error: 0.6010 - val_loss: 3.0412 - val_y1_output_loss: 0.5910 - val_y2_output_loss: 2.4502 - val_y1_output_root_mean_squared_error: 0.7688 - val_y2_output_root_mean_squared_error: 1.5653
# Epoch 473/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4732 - y1_output_loss: 0.1432 - y2_output_loss: 0.3300 - y1_output_root_mean_squared_error: 0.3785 - y2_output_root_mean_squared_error: 0.5745 - val_loss: 1.1713 - val_y1_output_loss: 0.2546 - val_y2_output_loss: 0.9167 - val_y1_output_root_mean_squared_error: 0.5046 - val_y2_output_root_mean_squared_error: 0.9575
# Epoch 474/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4002 - y1_output_loss: 0.1225 - y2_output_loss: 0.2777 - y1_output_root_mean_squared_error: 0.3499 - y2_output_root_mean_squared_error: 0.5270 - val_loss: 1.0888 - val_y1_output_loss: 0.2039 - val_y2_output_loss: 0.8848 - val_y1_output_root_mean_squared_error: 0.4516 - val_y2_output_root_mean_squared_error: 0.9407
# Epoch 475/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5820 - y1_output_loss: 0.1484 - y2_output_loss: 0.4336 - y1_output_root_mean_squared_error: 0.3853 - y2_output_root_mean_squared_error: 0.6585 - val_loss: 1.5133 - val_y1_output_loss: 0.3235 - val_y2_output_loss: 1.1899 - val_y1_output_root_mean_squared_error: 0.5687 - val_y2_output_root_mean_squared_error: 1.0908
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6188 - y1_output_loss: 0.1651 - y2_output_loss: 0.4537 - y1_output_root_mean_squared_error: 0.4063 - y2_output_root_mean_squared_error: 0.6736 - val_loss: 1.1150 - val_y1_output_loss: 0.2168 - val_y2_output_loss: 0.8982 - val_y1_output_root_mean_squared_error: 0.4656 - val_y2_output_root_mean_squared_error: 0.9477
# Epoch 477/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5178 - y1_output_loss: 0.1381 - y2_output_loss: 0.3797 - y1_output_root_mean_squared_error: 0.3717 - y2_output_root_mean_squared_error: 0.6162 - val_loss: 1.4225 - val_y1_output_loss: 0.2439 - val_y2_output_loss: 1.1786 - val_y1_output_root_mean_squared_error: 0.4939 - val_y2_output_root_mean_squared_error: 1.0856
# Epoch 478/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5935 - y1_output_loss: 0.1494 - y2_output_loss: 0.4441 - y1_output_root_mean_squared_error: 0.3865 - y2_output_root_mean_squared_error: 0.6664 - val_loss: 2.7254 - val_y1_output_loss: 0.2290 - val_y2_output_loss: 2.4965 - val_y1_output_root_mean_squared_error: 0.4785 - val_y2_output_root_mean_squared_error: 1.5800
# Epoch 479/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4668 - y1_output_loss: 0.1350 - y2_output_loss: 0.3319 - y1_output_root_mean_squared_error: 0.3674 - y2_output_root_mean_squared_error: 0.5761 - val_loss: 1.0908 - val_y1_output_loss: 0.2165 - val_y2_output_loss: 0.8743 - val_y1_output_root_mean_squared_error: 0.4653 - val_y2_output_root_mean_squared_error: 0.9351
# Epoch 480/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4562 - y1_output_loss: 0.1349 - y2_output_loss: 0.3213 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5668 - val_loss: 1.4092 - val_y1_output_loss: 0.3311 - val_y2_output_loss: 1.0781 - val_y1_output_root_mean_squared_error: 0.5754 - val_y2_output_root_mean_squared_error: 1.0383
# Epoch 481/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3673 - y1_output_loss: 0.1201 - y2_output_loss: 0.2471 - y1_output_root_mean_squared_error: 0.3466 - y2_output_root_mean_squared_error: 0.4971 - val_loss: 1.0818 - val_y1_output_loss: 0.2087 - val_y2_output_loss: 0.8731 - val_y1_output_root_mean_squared_error: 0.4569 - val_y2_output_root_mean_squared_error: 0.9344
# Epoch 482/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4841 - y1_output_loss: 0.1512 - y2_output_loss: 0.3329 - y1_output_root_mean_squared_error: 0.3889 - y2_output_root_mean_squared_error: 0.5769 - val_loss: 1.3867 - val_y1_output_loss: 0.3532 - val_y2_output_loss: 1.0335 - val_y1_output_root_mean_squared_error: 0.5943 - val_y2_output_root_mean_squared_error: 1.0166
# Epoch 483/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3981 - y1_output_loss: 0.1299 - y2_output_loss: 0.2682 - y1_output_root_mean_squared_error: 0.3605 - y2_output_root_mean_squared_error: 0.5179 - val_loss: 1.3706 - val_y1_output_loss: 0.1943 - val_y2_output_loss: 1.1763 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 1.0846
# Epoch 484/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4277 - y1_output_loss: 0.1349 - y2_output_loss: 0.2929 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5412 - val_loss: 1.1721 - val_y1_output_loss: 0.2171 - val_y2_output_loss: 0.9550 - val_y1_output_root_mean_squared_error: 0.4659 - val_y2_output_root_mean_squared_error: 0.9772
# Epoch 485/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5222 - y1_output_loss: 0.1425 - y2_output_loss: 0.3797 - y1_output_root_mean_squared_error: 0.3775 - y2_output_root_mean_squared_error: 0.6162 - val_loss: 1.9414 - val_y1_output_loss: 0.2416 - val_y2_output_loss: 1.6997 - val_y1_output_root_mean_squared_error: 0.4916 - val_y2_output_root_mean_squared_error: 1.3037
# Epoch 486/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4477 - y1_output_loss: 0.1345 - y2_output_loss: 0.3132 - y1_output_root_mean_squared_error: 0.3667 - y2_output_root_mean_squared_error: 0.5596 - val_loss: 2.6904 - val_y1_output_loss: 0.3420 - val_y2_output_loss: 2.3484 - val_y1_output_root_mean_squared_error: 0.5848 - val_y2_output_root_mean_squared_error: 1.5325
# Epoch 487/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4177 - y1_output_loss: 0.1371 - y2_output_loss: 0.2806 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.5297 - val_loss: 2.1962 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 1.9920 - val_y1_output_root_mean_squared_error: 0.4519 - val_y2_output_root_mean_squared_error: 1.4114
# Epoch 488/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5019 - y1_output_loss: 0.1445 - y2_output_loss: 0.3575 - y1_output_root_mean_squared_error: 0.3801 - y2_output_root_mean_squared_error: 0.5979 - val_loss: 1.8983 - val_y1_output_loss: 0.3946 - val_y2_output_loss: 1.5037 - val_y1_output_root_mean_squared_error: 0.6281 - val_y2_output_root_mean_squared_error: 1.2263
# Epoch 489/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4682 - y1_output_loss: 0.1474 - y2_output_loss: 0.3208 - y1_output_root_mean_squared_error: 0.3839 - y2_output_root_mean_squared_error: 0.5664 - val_loss: 1.7256 - val_y1_output_loss: 0.2711 - val_y2_output_loss: 1.4545 - val_y1_output_root_mean_squared_error: 0.5206 - val_y2_output_root_mean_squared_error: 1.2060
# Epoch 490/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3490 - y1_output_loss: 0.1244 - y2_output_loss: 0.2246 - y1_output_root_mean_squared_error: 0.3527 - y2_output_root_mean_squared_error: 0.4739 - val_loss: 1.8171 - val_y1_output_loss: 0.3424 - val_y2_output_loss: 1.4748 - val_y1_output_root_mean_squared_error: 0.5851 - val_y2_output_root_mean_squared_error: 1.2144
# Epoch 491/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3551 - y1_output_loss: 0.1165 - y2_output_loss: 0.2386 - y1_output_root_mean_squared_error: 0.3413 - y2_output_root_mean_squared_error: 0.4884 - val_loss: 1.5940 - val_y1_output_loss: 0.2340 - val_y2_output_loss: 1.3599 - val_y1_output_root_mean_squared_error: 0.4838 - val_y2_output_root_mean_squared_error: 1.1662
# Epoch 492/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6386 - y1_output_loss: 0.1398 - y2_output_loss: 0.4988 - y1_output_root_mean_squared_error: 0.3739 - y2_output_root_mean_squared_error: 0.7063 - val_loss: 1.0593 - val_y1_output_loss: 0.2165 - val_y2_output_loss: 0.8428 - val_y1_output_root_mean_squared_error: 0.4653 - val_y2_output_root_mean_squared_error: 0.9180
# Epoch 493/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5605 - y1_output_loss: 0.1481 - y2_output_loss: 0.4124 - y1_output_root_mean_squared_error: 0.3848 - y2_output_root_mean_squared_error: 0.6422 - val_loss: 1.5137 - val_y1_output_loss: 0.2282 - val_y2_output_loss: 1.2855 - val_y1_output_root_mean_squared_error: 0.4778 - val_y2_output_root_mean_squared_error: 1.1338
# Epoch 494/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4089 - y1_output_loss: 0.1284 - y2_output_loss: 0.2805 - y1_output_root_mean_squared_error: 0.3584 - y2_output_root_mean_squared_error: 0.5296 - val_loss: 2.4990 - val_y1_output_loss: 0.2019 - val_y2_output_loss: 2.2971 - val_y1_output_root_mean_squared_error: 0.4494 - val_y2_output_root_mean_squared_error: 1.5156
# Epoch 495/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4189 - y1_output_loss: 0.1205 - y2_output_loss: 0.2984 - y1_output_root_mean_squared_error: 0.3471 - y2_output_root_mean_squared_error: 0.5463 - val_loss: 1.1765 - val_y1_output_loss: 0.2749 - val_y2_output_loss: 0.9016 - val_y1_output_root_mean_squared_error: 0.5243 - val_y2_output_root_mean_squared_error: 0.9495
# Epoch 496/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4388 - y1_output_loss: 0.1337 - y2_output_loss: 0.3051 - y1_output_root_mean_squared_error: 0.3657 - y2_output_root_mean_squared_error: 0.5524 - val_loss: 1.0579 - val_y1_output_loss: 0.1959 - val_y2_output_loss: 0.8620 - val_y1_output_root_mean_squared_error: 0.4426 - val_y2_output_root_mean_squared_error: 0.9285
# Epoch 497/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.5792 - y1_output_loss: 0.3786 - y2_output_loss: 1.2007 - y1_output_root_mean_squared_error: 0.6153 - y2_output_root_mean_squared_error: 1.0958 - val_loss: 1.1803 - val_y1_output_loss: 0.3008 - val_y2_output_loss: 0.8794 - val_y1_output_root_mean_squared_error: 0.5485 - val_y2_output_root_mean_squared_error: 0.9378
# Epoch 498/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3491 - y1_output_loss: 0.1213 - y2_output_loss: 0.2277 - y1_output_root_mean_squared_error: 0.3483 - y2_output_root_mean_squared_error: 0.4772 - val_loss: 2.0039 - val_y1_output_loss: 0.4384 - val_y2_output_loss: 1.5655 - val_y1_output_root_mean_squared_error: 0.6621 - val_y2_output_root_mean_squared_error: 1.2512
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3791 - y1_output_loss: 0.1217 - y2_output_loss: 0.2574 - y1_output_root_mean_squared_error: 0.3488 - y2_output_root_mean_squared_error: 0.5074 - val_loss: 1.9556 - val_y1_output_loss: 0.2060 - val_y2_output_loss: 1.7495 - val_y1_output_root_mean_squared_error: 0.4539 - val_y2_output_root_mean_squared_error: 1.3227
# Epoch 500/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4004 - y1_output_loss: 0.1279 - y2_output_loss: 0.2725 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.5221 - val_loss: 1.6102 - val_y1_output_loss: 0.3740 - val_y2_output_loss: 1.2362 - val_y1_output_root_mean_squared_error: 0.6116 - val_y2_output_root_mean_squared_error: 1.1118

# %% [markdown]
# Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 1.6102 - y1_output_loss: 0.3740 - y2_output_loss: 1.2362 - y1_output_root_mean_squared_error: 0.6116 - y2_output_root_mean_squared_error: 1.1118
# Loss = 1.610216498374939, Y1_loss = 0.37403762340545654, Y1_mse = 0.6115861535072327, Y2_loss = 1.2361787557601929, Y2_mse = 1.1118357181549072

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
